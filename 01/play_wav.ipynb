# %% [markdown]
# <a href="https://colab.research.google.com/github/Ryusan09/MultivariatAanalysis/blob/main/play_wav.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Google Colab上でのwavファイルの再生
#
# セルを順に実行していきましょう

# %%
from scipy.io import wavfile
from IPython.display import Audio # 音声を再生するためのおまじない

# %%
# google driveのマウント
# 左上のフォルダマークから「ドライブをマウント」をクリックしてもOK
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Wavファイルの置き場所を指定（各自が編集）
# Google Driveのマイドライブの場所は「/content/drive/MyDrive/」なので，
# そこを起点に置き場所を指定
IN_WAVE_FILE = "/content/drive/MyDrive/n-hon-knock/data/in.wav"

# %%
# 音声ファイルを開く
sr, data = wavfile.read(IN_WAVE_FILE)

# %%
# 再生して確認
Audio(IN_WAVE_FILE)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

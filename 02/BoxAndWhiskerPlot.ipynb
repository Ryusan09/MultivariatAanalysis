# %%
import matplotlib.pyplot as plt
import numpy as np

data = [
    13, 60, 81, 75, 65, 64, 48, 58, 49, 60, 87, 65, 78, 45, 61, 60, 59, 44, 24, 9, 14, 30, 96, 40, 45, 53, 70, 21,
]
data = np.array(data)
fig, ax = plt.subplots()
ax.boxplot(data)
plt.show()

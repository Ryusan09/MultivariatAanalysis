# %% [markdown]
# ## その1
#
# 次のデータ表（data3_2.csv）は学生20人について，英語，国語，数学の試験の結果を記録したものである．
#
#
# (1) 国語について，以下の統計量とグラフを作成せよ．
#
#
# 1.   平均値，中央値，最小値，最大値，第1四分位数，第3四分位数
# 2.   ヒストグラム
# 3.   箱ひげ図
# 4.   幹葉図
#
# (2) データ表からデータフレームを作成して，英語，国語，数学の散布図行列を作成せよ．
#
#
# |学生番号|国語|英語|数学|
# |:-:|:-:|:-:|:-:|
# |1|65|68|55|
# |2|37|56|30|
# |3|24|49|26|
# |4|54|66|45|
# |5|27|46|41|
# |6|46|60|38|
# |7|42|59|47|
# |8|34|54|37|
# |9|44|57|51|
# |10|39|53|45|
# |11|40|54|32|
# |12|35|58|38|
# |13|39|58|39|
# |14|37|52|52|
# |15|36|54|36|
# |16|49|58|48|
# |17|43|57|38|
# |18|22|48|32|
# |19|32|52|40|
# |20|42|55|51|

# %% [markdown]
# ## その2
#
# 以下の表（data4_6.csv）について，
#
# 目的変数を売上$y$，説明変数を温度$x$とする回帰式を求めよ（単回帰分析）．
#
#
# |No.|売上y|温度x|天気|
# |:-:|:-:|:-:|:-:|
# |1|52|27.3|0|
# |2|56|27.9|1|
# |3|62|27.7|1|
# |4|50|27|1|
# |5|64|28.1|0|
# |6|70|28|0|
# |7|70|28.5|1|
# |8|78|28.2|0|
# |9|78|28.6|0|
# |10|74|29|1|
# |11|60|28|0|
# |12|82|28.9|0|
# |13|70|28.4|1|
# |14|82|28.9|0|
# |15|86|28.7|0|
# |16|84|29.3|0|
# |17|84|29.9|1|
# |18|88|29.2|0|
# |19|90|29.6|1|
# |20|94|30|1|
# |21|98|29.5|0|
# |22|98|30.7|1|
# |23|98|30.3|0|
# |24|80|29|1|
# |25|104|30.3|0|
# |26|106|30.7|1|
# |27|100|30|0|
# |28|110|30.6|1|
# |29|108|31|1|
# |30|120|31|0|
